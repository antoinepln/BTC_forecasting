# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
from utility_function import get_X_y_DNN , DNN_model, plot_loss
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from tensorflow.keras.layers import Dense , Input , LSTM, Bidirectional, Dropout
from tensorflow.keras.models import Model , Sequential
from tensorflow.keras import regularizers
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

# %%
def init_model(length, n_days, features) :
    model = Sequential()
    model.add(Dense(85,activation = 'relu',input_dim=(20)))
    model.add(Dense(40,activation = 'relu'))
    model.add(Dense(1,activation = 'sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

def get_sample(df, length, temporal_horizon, style, start):

    temporal_horizon = temporal_horizon - 1
    last_possible = df.shape[0] - temporal_horizon - length

    if style == "linear" :
        X_sample = df.drop(columns = 'price').iloc[start: start+length].values
        y_sample = df['price'].iloc[start+length: start+length+temporal_horizon+1].values
        return X_sample, y_sample
    if style == "clf" :
        X_sample = df.drop(columns = 'up').iloc[start: start+length].values
        y_sample = df['up'].iloc[start+length+temporal_horizon-1: start+length+temporal_horizon].values
        return X_sample, y_sample

def get_X_y(df, temporal_horizon, length, style):
    X, y = [], []

    for len_ in range(len(df)-temporal_horizon -length):
        xi, yi = get_sample(df, length, temporal_horizon, style , len_)
        X.append(xi)
        y.append(yi)

    return X, y

# %%
df  = pd.read_csv('data_2.csv').set_index('date').dropna()

# %%
up = [0,0,0,0,0,0,0]
for i in range(7,len(df)):
    if df['close'].iloc[i] > df['close'].iloc[i-7] :
        up.append(1)
    else :
        up.append(0)
df['up'] = up

# %%
n_days = 1
length = 20
n = 1880
s = 2610
df_test = df.iloc[s-length+11*90:s+90+11*90]
df_ = df.iloc[n+11*90:s+11*90]

# %%
scaler = MinMaxScaler()
scaler.fit(df_)
df_[df_.columns] =  scaler.transform(df_)
df_test[df_.columns] =  scaler.transform(df_test)
# Out:
# /Users/antoine/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/antoine/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /Users/antoine/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/antoine/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
model = init_model(length, n_days,17)

# %%
X_train, y_train = get_X_y(df_, n_days, length, 'clf')

# %%
es = EarlyStopping(monitor = 'val_accuracy',mode = 'min' , verbose = 1, patience = 30, restore_best_weights = True)

# %%
history = model.fit(np.array(X_train), np.array(y_train),
                    validation_split = 0.3,
                    callbacks = [es],
                    epochs = 500,
                    batch_size = 64,
                    verbose = True,
                    shuffle = True)
# Out:
# Epoch 1/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6973 - accuracy: 0.4980 - val_loss: 0.6951 - val_accuracy: 0.4789
# Epoch 2/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6918 - accuracy: 0.5181 - val_loss: 0.6910 - val_accuracy: 0.5117
# Epoch 3/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.5222 - val_loss: 0.6908 - val_accuracy: 0.5117
# Epoch 4/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6917 - accuracy: 0.5202 - val_loss: 0.6908 - val_accuracy: 0.5164
# Epoch 5/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.5222 - val_loss: 0.6915 - val_accuracy: 0.5822
# Epoch 6/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 0.5383 - val_loss: 0.6906 - val_accuracy: 0.4977
# Epoch 7/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 0.5222 - val_loss: 0.6904 - val_accuracy: 0.5211
# Epoch 8/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.5282 - val_loss: 0.6900 - val_accuracy: 0.5117
# Epoch 9/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6912 - accuracy: 0.5222 - val_loss: 0.6913 - val_accuracy: 0.5728
# Epoch 10/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.5383 - val_loss: 0.6897 - val_accuracy: 0.4836
# Epoch 11/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6905 - accuracy: 0.5222 - val_loss: 0.6904 - val_accuracy: 0.5117
# Epoch 12/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5282 - val_loss: 0.6899 - val_accuracy: 0.5352
# Epoch 13/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5343 - val_loss: 0.6920 - val_accuracy: 0.5023
# Epoch 14/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.5323 - val_loss: 0.6896 - val_accuracy: 0.5352
# Epoch 15/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6888 - accuracy: 0.5323 - val_loss: 0.6894 - val_accuracy: 0.4883
# Epoch 16/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.5524 - val_loss: 0.6906 - val_accuracy: 0.5681
# Epoch 17/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.5302 - val_loss: 0.6894 - val_accuracy: 0.5493
# Epoch 18/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.5403 - val_loss: 0.6893 - val_accuracy: 0.4883
# Epoch 19/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.5383 - val_loss: 0.6897 - val_accuracy: 0.5587
# Epoch 20/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.5323 - val_loss: 0.6892 - val_accuracy: 0.5493
# Epoch 21/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.5403 - val_loss: 0.6897 - val_accuracy: 0.5587
# Epoch 22/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.5484 - val_loss: 0.6888 - val_accuracy: 0.5305
# Epoch 23/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.5343 - val_loss: 0.6886 - val_accuracy: 0.5258
# Epoch 24/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.5383 - val_loss: 0.6885 - val_accuracy: 0.5305
# Epoch 25/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6874 - accuracy: 0.5343 - val_loss: 0.6892 - val_accuracy: 0.5634
# Epoch 26/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6873 - accuracy: 0.5302 - val_loss: 0.6902 - val_accuracy: 0.5681
# Epoch 27/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.5464 - val_loss: 0.6887 - val_accuracy: 0.4836
# Epoch 28/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6867 - accuracy: 0.5323 - val_loss: 0.6885 - val_accuracy: 0.5399
# Epoch 29/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6863 - accuracy: 0.5403 - val_loss: 0.6893 - val_accuracy: 0.5822
# Epoch 30/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6868 - accuracy: 0.5464 - val_loss: 0.6885 - val_accuracy: 0.5587
# Epoch 31/500
# 1/8 [==>...........................] - ETA: 0s - loss: 0.6990 - accuracy: 0.4219Restoring model weights from the end of the best epoch.
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6868 - accuracy: 0.5323 - val_loss: 0.6888 - val_accuracy: 0.4930
# Epoch 00031: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model loss')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best')
plt.show()

# %%
pred_ = []
pred = []
for x in range(len(df_test)-length):
    y = df_test['ath'][x:x+length].values.ravel()
    y.shape = (1,20)
    predict = model.predict(y)
    pred_.append(predict)
    if predict > 0.1: 
        pred.append(1)
    else : 
        pred.append(0)
accuracy = accuracy_score(df_test['up'][length:].values, np.array(pred).ravel())
#tn, fp, fn, tp = confusion_matrix(df_test['up'][length:].values, np.array(pred).ravel()).ravel()

# %%
accuracy
# Out:
# 0.0

# %%
tp/(tp+fn)
# Out:
# 0.8367346938775511

# %%
tn / (tn+fp)
# Out:
# 0.1951219512195122

# %%
df[:30]
# Out:
#                close     rsi_14      macd  william_a/d       ATR       ath  \
# date
# 2010-08-24 -2.733368  52.334489  0.000470    -3.732089 -5.278403  0.698399
# 2010-08-25 -2.736450  52.077594  0.000350    -3.803268 -5.480473  0.696250
# 2010-08-26 -2.748872  50.999206  0.000191    -3.887439 -5.553892  0.687654
# 2010-10-15    0.983756       6.006353  23.218016            5.017280
# 2010-10-16    0.965275       6.555357  23.589289            5.209486
#
#             utxo_spent  up
# date
# 2010-08-24    6.624065   0
# 2010-08-25    5.438079   0
# 2010-08-26    6.001415   0
# 2010-08-27    5.541264   0
# 2010-08-28    5.872118   0
# 2010-08-29    5.123964   0
# 2010-08-30    5.863631   0
# 2010-08-31    6.645091   0
# 2010-09-01    6.306275   0
# 2010-09-02    5.843544   0
# 2010-09-03    5.501258   0
# 2010-09-04    5.323010   0
# 2010-09-05    5.700444   0
# 2010-09-06    5.602119   0
# 2010-09-07    5.389072   1
# 2010-09-08    5.680173   0
# 2010-09-09    5.820083   0
# 2010-09-10    5.733341   1
# 2010-09-11    5.429346   1
# 2010-09-12    6.204558   0
# 2010-09-13    6.200509   1
# 2010-10-08    6.368187   1
# 2010-10-09    6.361302   1
# 2010-10-10    5.926926   1
# 2010-10-11    5.924256   1
# 2010-10-12    5.966147   1
# 2010-10-13    6.573680   1
# 2010-10-14    5.983936   1
# 2010-10-15    5.700444   1
# 2010-10-16    6.366470   1

# %%
y_sample = df['up'].iloc[2+5+7-1: 2+5+7]

# %%
df['up'].iloc[13]
# Out:
# 0

# %%
y_sample
# Out:
# date
# 2010-09-06    0
# Name: up, dtype: int64

# %%
df.drop(columns = 'up').iloc[2: 7].values
# Out:
# array([[-2.74887220e+00,  5.09992057e+01,  1.91259577e-04,
#         -3.88743880e+00, -5.55389188e+00,  6.87654454e-01,
#          5.84932478e+00,  1.00284605e+00,  6.07534603e+00,
#         -6.30414792e+00,  7.26189425e-01,  6.63443367e+01,
#          9.04389859e-01,  6.12029742e+00,  2.23230806e+01,
#          5.06259503e+00,  6.00141488e+00],
#        [-2.73336801e+00,  5.23280733e+01,  1.41335072e-04,
#         -3.79433874e+00, -5.58100242e+00,  6.98399054e-01,
#          5.70378247e+00,  1.02381934e+00,  5.87493073e+00,
#         -6.55455860e+00,  7.07063214e-01,  6.62853350e+01,
#          9.22312445e-01,  5.80513497e+00,  2.23905548e+01,
#          4.81218436e+00,  5.54126355e+00],
#        [-2.73954087e+00,  5.17238271e+01,  6.97959126e-05,
#         -3.81227823e+00, -5.65081736e+00,  6.94101214e-01,
#          5.85793315e+00,  1.00425652e+00,  6.07073773e+00,
#         -6.23684424e+00,  7.37286887e-01,  6.68642239e+01,
#          9.09933686e-01,  5.90808294e+00,  2.23864269e+01,
#          5.12989871e+00,  5.87211779e+00],
#        [-2.74887220e+00,  5.07766758e+01, -3.33843017e-05,
#         -3.84446820e+00, -5.67759273e+00,  6.87654454e-01,
#          5.57594910e+00,  9.60926696e-01,  5.74300319e+00,
#         -6.78177548e+00,  7.04765205e-01,  6.64344278e+01,
#          8.96496045e-01,  5.44241771e+00,  2.23403947e+01,
#          4.58496748e+00,  5.12396398e+00],
#        [-2.73382965e+00,  5.22974864e+01, -3.86600544e-05,
#         -2.91400893e+00, -5.23072548e+00,  6.98076716e-01,
#          5.77765232e+00,  9.75308316e-01,  6.04500531e+00,
#         -6.17378610e+00,  6.19455827e-01,  6.49803222e+01,
#          9.24879913e-01,  5.92958914e+00,  2.22509070e+01,
#          5.19295685e+00,  5.86363118e+00]])
