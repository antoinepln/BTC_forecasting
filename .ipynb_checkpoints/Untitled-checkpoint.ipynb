# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
from utility_function import wavelet_transform, get_sample,get_X_y, autoencoder, init_model, plot_loss
from train_model import Trainer
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv('data.csv').set_index('date').dropna()

# %%
return_trim = {}
return_hold = {}
detail_perf = {}
detail = []
n_days = 1
length = 5

df_test = df[820-length:910]
df_ = df[:820]
t = Trainer(df_, df_test, 1, 5)
t.get_perf()
return_trim[0] = t.perf


return_hold[0] = t.hold

detail.append(t.min)
detail.append(t.max)
detail.append(t.long)
detail.append(t.up)
# Out:
# /Users/antoine/code/BTC_forecasting/BTC_forecasting/train_model.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[x] = wavelet_transform(df[x])
# /Users/antoine/code/BTC_forecasting/BTC_forecasting/train_model.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns]  = self.scaler.transform(df)
# /Users/antoine/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/frame.py:3072: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.iloc._setitem_with_indexer((slice(None), indexer), value)
# /Users/antoine/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/frame.py:3037: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_array(key, value)
# Restoring model weights from the end of the best epoch.
# Epoch 00098: early stopping
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# WARNING:tensorflow:Model was constructed with shape (None, 1, 23) for input Tensor("input_8:0", shape=(None, 1, 23), dtype=float32), but it was called on an input with incompatible shape (None, 23).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-06b2cba70a62> in <module>
#       9 df_ = df[:820]
#      10 t = Trainer(df_, df_test, 1, 5)
# ---> 11 t.get_perf()
#      12 return_trim[0] = t.perf
#      13
#
# ~/code/BTC_forecasting/BTC_forecasting/train_model.py in get_perf(self)
#      75
#      76     def get_perf(self) :
# ---> 77         self.get_prediction()
#      78         prediction = self.prediction
#      79         df_test = self.df_test[self.length:]
#
# ~/code/BTC_forecasting/BTC_forecasting/train_model.py in get_prediction(self)
#      71     def get_prediction(self) :
#      72         self.train()
# ---> 73         self.prediction = get_prediction(self.df_test,self.length, 90, self.autoencoder, self.model, self.scaler)
#      74
#      75
#
# ~/code/BTC_forecasting/BTC_forecasting/utility_function.py in get_prediction(df_test, length, period_test, autoencoder, model, scaler)
#     102
#     103     prediction = np.array(prediction)
# --> 104     prediction.shape = (period_test)
#     105
#     106     return prediction
#
# ValueError: cannot reshape array of size 91 into shape (90,)

# %%
return_trim
# Out:
# {0: 0.14552134751127604}

# %%
df_test
# Out:
#                  close        open        high         low     rsi_14  \
# date
# 2013-01-15    0.224183    0.176580    0.130636    0.236836   0.284610
# 2013-01-16    0.224183    0.176580    0.130636    0.236836   0.284610
# 2013-01-17    0.320032    0.266710    0.212722    0.343374   0.595824
# 2013-01-18    0.320032    0.266710    0.212722    0.343374   0.595824
# 2013-01-19    0.320032    0.266710    0.212722    0.343374   0.595824
# ...                ...         ...         ...         ...        ...
# 2013-04-16   67.979819   73.994000   80.376475   51.387891  41.991971
